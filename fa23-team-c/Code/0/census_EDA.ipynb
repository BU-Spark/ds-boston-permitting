# %% [markdown]
# ## Census Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
data = pd.read_csv("../data/census_data.csv")

# Display the first few rows of the data to get an overview
#data.head()
#data.info() # Get data types and missing values
#data.describe()  # Summary statistics
#data.isnull().sum()
# Define row ranges for each table
df = data

# Identify the rows where the first item is in all caps and others are empty
header_rows = df[df.iloc[:, 0].str.isupper() & df.iloc[:, 1:].isnull().all(axis=1)]

# Create subtables and display them separately
subtables = []
for i in range(len(header_rows)):
    if i == len(header_rows) - 1:
        subtable = df.iloc[header_rows.index[i]:]
    else:
        subtable = df.iloc[header_rows.index[i]:header_rows.index[i + 1]]
    subtables.append(subtable)

# Display subtables
for i, subtable in enumerate(subtables):
    display(subtable)
    
# for i in range(len(header_rows)):
#     if i == len(header_rows) - 1:
#         subtable = df.iloc[header_rows.index[i]:]
#     else:
#         subtable = df.iloc[header_rows.index[i]:header_rows.index[i + 1]]
    
#     # Perform EDA on the current subtable
#     print(f"Exploratory Data Analysis for Subtable {i + 1}:")
#     display(subtable.describe())  # Summary statistics
#     display(subtable.info())      # Data types and missing values
    
#     # Plot relevant columns for visualization
#     columns_to_plot = subtable.select_dtypes(include=[np.number]).columns
#     if len(columns_to_plot) > 0:
#         plt.figure(figsize=(12, 6))
#         sns.pairplot(subtable[columns_to_plot])
#         plt.title(f"Pairplot for Subtable {i + 1}")
#         plt.show()
#     else:
#         print("No numeric columns to plot.")
    
#     print("\n" + "="*50 + "\n")  # Separation for clarity

# Subtable 1: HOUSING OCCUPANCY
data["Label (Grouping)"] = data["Label (Grouping)"].str.strip()
housing_occupancy = data[data["Label (Grouping)"].isin(["Occupied housing units", 
                                                       "Vacant housing units", 
                                                       "Homeowner vacancy rate", 
                                                       "Rental vacancy rate"])]
occupancy_types = ["Occupied", "Vacant", "Homeowner Vacancy", "Rental Vacancy"]
occupancy_counts = housing_occupancy

# Extract relevant data for the plot
labels = housing_occupancy["Label (Grouping)"]
values = housing_occupancy["ZCTA5 02215!!Estimate"].str.replace(',', '').astype(float)

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(labels, values, color='skyblue')
plt.xlabel("Housing Categories")
plt.ylabel("# of units")
plt.title("Housing Categories in ZCTA5 02215")
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# Subtable 2: Units in structure
data["Label (Grouping)"] = data["Label (Grouping)"].str.strip()
unit_data = data[data["Label (Grouping)"].isin(["1-unit, detached", 
                                                       "1-unit, attached", 
                                                       "2 units", 
                                                       "3 or 4 units",
                                                       "5 to 9 units",
                                                       "10 to 19 units",
                                                       "20 or more units",
                                                       "Mobile home",
                                                       "Boat, RV, van, etc."])]

# Extract relevant data for the plot
labels = unit_data["Label (Grouping)"]
values = unit_data["ZCTA5 02215!!Estimate"].str.replace(',', '').astype(float)
# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(labels, values, color='skyblue')
plt.xlabel("Unit types")
plt.ylabel("# of units")
plt.title("Units in structure in ZCTA5 02215")
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# Subtable 3: Year structure built
data["Label (Grouping)"] = data["Label (Grouping)"].str.strip()
unit_data = data[data["Label (Grouping)"].isin(["Built 2020 or later", 
                                                       "Built 2010 to 2019", 
                                                       "Built 2000 to 2009", 
                                                       "Built 1990 to 1999",
                                                       "Built 1980 to 1989",
                                                       "Built 1970 to 1979",
                                                       "Built 1960 to 1969",
                                                       "Built 1950 to 1959",
                                                       "Built 1940 to 1949",
                                                       "Built 1939 or earlier"])]

# Extract relevant data for the plot
labels = unit_data["Label (Grouping)"]
values = unit_data["ZCTA5 02215!!Estimate"].str.replace(',', '').astype(float)
# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(labels, values, color='skyblue')
plt.xlabel("Year structure built")
plt.ylabel("# of units")
plt.title("Year structure built in ZCTA5 02215")
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
#                  Label (Grouping) ZCTA5 02215!!Estimate  \
# 0               HOUSING OCCUPANCY                   NaN
# 1             Total housing units                 8,908
# 2          Occupied housing units                 7,931
# 3            Vacant housing units                   977
# 4          Homeowner vacancy rate                   0.0
# 5             Rental vacancy rate                   3.3
#
#   ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 0                          NaN                  NaN
# 1                         ±612                8,908
# 2                         ±567                89.0%
# 3                         ±228                11.0%
# 4                         ±5.2                  (X)
# 5                         ±1.6                  (X)
#
#   ZCTA5 02215!!Percent Margin of Error
# 0                                  NaN
# 1                                  (X)
# 2                                 ±2.4
# 3                                 ±2.4
# 4                                  (X)
# 5                                  (X)
#                Label (Grouping) ZCTA5 02215!!Estimate  \
# 6            UNITS IN STRUCTURE                   NaN
# 7           Total housing units                 8,908
# 8              1-unit, detached                   101
# 9              1-unit, attached                    38
# 10                      2 units                    86
# 11                 3 or 4 units                   156
# 12                 5 to 9 units                   989
# 13               10 to 19 units                 1,716
# 14             20 or more units                 5,819
# 15                  Mobile home                     0
# 16          Boat, RV, van, etc.                     3
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 6                           NaN                  NaN
# 7                          ±612                8,908
# 8                           ±61                 1.1%
# 9                           ±42                 0.4%
# 10                          ±61                 1.0%
# 11                          ±92                 1.8%
# 12                         ±207                11.1%
# 13                         ±340                19.3%
# 14                         ±615                65.3%
# 15                          ±25                 0.0%
# 16                           ±7                 0.0%
#
#    ZCTA5 02215!!Percent Margin of Error
# 6                                   NaN
# 7                                   (X)
# 8                                  ±0.7
# 9                                  ±0.5
# 10                                 ±0.7
# 11                                 ±1.0
# 12                                 ±2.3
# 13                                 ±3.8
# 14                                 ±3.9
# 15                                 ±0.4
# 16                                 ±0.1
#                  Label (Grouping) ZCTA5 02215!!Estimate  \
# 17           YEAR STRUCTURE BUILT                   NaN
# 18            Total housing units                 8,908
# 19            Built 2020 or later                    65
# 20             Built 2010 to 2019                   843
# 21             Built 2000 to 2009                 1,021
# 22             Built 1990 to 1999                   507
# 23             Built 1980 to 1989                   302
# 24             Built 1970 to 1979                   357
# 25             Built 1960 to 1969                   583
# 26             Built 1950 to 1959                   345
# 27             Built 1940 to 1949                   540
# 28          Built 1939 or earlier                 4,345
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 17                          NaN                  NaN
# 18                         ±612                8,908
# 19                          ±73                 0.7%
# 20                         ±184                 9.5%
# 21                         ±232                11.5%
# 22                         ±143                 5.7%
# 23                          ±98                 3.4%
# 24                         ±110                 4.0%
# 25                         ±190                 6.5%
# 26                         ±116                 3.9%
# 27                         ±216                 6.1%
# 28                         ±562                48.8%
#
#    ZCTA5 02215!!Percent Margin of Error
# 17                                  NaN
# 18                                  (X)
# 19                                 ±0.8
# 20                                 ±2.1
# 21                                 ±2.7
# 22                                 ±1.5
# 23                                 ±1.1
# 24                                 ±1.3
# 25                                 ±2.1
# 26                                 ±1.3
# 27                                 ±2.4
# 28                                 ±4.0
#            Label (Grouping) ZCTA5 02215!!Estimate  \
# 29                    ROOMS                   NaN
# 30      Total housing units                 8,908
# 31                   1 room                 2,103
# 32                  2 rooms                 1,753
# 33                  3 rooms                 2,496
# 34                  4 rooms                 1,693
# 35                  5 rooms                   483
# 36                  6 rooms                   173
# 37                  7 rooms                    74
# 38                  8 rooms                    19
# 39          9 rooms or more                   114
# 40             Median rooms                   2.7
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 29                          NaN                  NaN
# 30                         ±612                8,908
# 31                         ±377                23.6%
# 32                         ±386                19.7%
# 33                         ±368                28.0%
# 34                         ±456                19.0%
# 35                         ±121                 5.4%
# 36                          ±70                 1.9%
# 37                          ±60                 0.8%
# 38                          ±22                 0.2%
# 39                          ±67                 1.3%
# 40                         ±0.2                  (X)
#
#    ZCTA5 02215!!Percent Margin of Error
# 29                                  NaN
# 30                                  (X)
# 31                                 ±4.2
# 32                                 ±3.8
# 33                                 ±4.2
# 34                                 ±4.6
# 35                                 ±1.4
# 36                                 ±0.8
# 37                                 ±0.7
# 38                                 ±0.2
# 39                                 ±0.8
# 40                                  (X)
#               Label (Grouping) ZCTA5 02215!!Estimate  \
# 41                    BEDROOMS                   NaN
# 42         Total housing units                 8,908
# 43                  No bedroom                 2,523
# 44                   1 bedroom                 3,369
# 45                  2 bedrooms                 2,481
# 46                  3 bedrooms                   372
# 47                  4 bedrooms                    91
# 48          5 or more bedrooms                    72
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 41                          NaN                  NaN
# 42                         ±612                8,908
# 43                         ±471                28.3%
# 44                         ±351                37.8%
# 45                         ±452                27.9%
# 46                         ±109                 4.2%
# 47                          ±51                 1.0%
# 48                          ±60                 0.8%
#
#    ZCTA5 02215!!Percent Margin of Error
# 41                                  NaN
# 42                                  (X)
# 43                                 ±4.4
# 44                                 ±4.2
# 45                                 ±4.2
# 46                                 ±1.3
# 47                                 ±0.5
# 48                                 ±0.7
#                                      Label (Grouping) ZCTA5 02215!!Estimate  \
# 49                                     HOUSING TENURE                   NaN
# 50                             Occupied housing units                 7,931
# 51                                     Owner-occupied                   703
# 52                                    Renter-occupied                 7,228
# 53          Average household size of owner-occupi...                  1.44
# 54          Average household size of renter-occup...                  1.62
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 49                          NaN                  NaN
# 50                         ±567                7,931
# 51                         ±149                 8.9%
# 52                         ±582                91.1%
# 53                        ±0.17                  (X)
# 54                        ±0.08                  (X)
#
#    ZCTA5 02215!!Percent Margin of Error
# 49                                  NaN
# 50                                  (X)
# 51                                 ±2.0
# 52                                 ±2.0
# 53                                  (X)
# 54                                  (X)
#                      Label (Grouping) ZCTA5 02215!!Estimate  \
# 55   YEAR HOUSEHOLDER MOVED INTO UNIT                   NaN
# 56             Occupied housing units                 7,931
# 57             Moved in 2019 or later                 2,172
# 58              Moved in 2015 to 2018                 3,701
# 59              Moved in 2010 to 2014                   975
# 60              Moved in 2000 to 2009                   606
# 61              Moved in 1990 to 1999                   274
# 62          Moved in 1989 and earlier                   203
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 55                          NaN                  NaN
# 56                         ±567                7,931
# 57                         ±450                27.4%
# 58                         ±339                46.7%
# 59                         ±369                12.3%
# 60                         ±231                 7.6%
# 61                         ±112                 3.5%
# 62                          ±76                 2.6%
#
#    ZCTA5 02215!!Percent Margin of Error
# 55                                  NaN
# 56                                  (X)
# 57                                 ±4.9
# 58                                 ±5.0
# 59                                 ±4.2
# 60                                 ±2.9
# 61                                 ±1.4
# 62                                 ±1.0
#                         Label (Grouping) ZCTA5 02215!!Estimate  \
# 63                    VEHICLES AVAILABLE                   NaN
# 64                Occupied housing units                 7,931
# 65                 No vehicles available                 4,738
# 66                   1 vehicle available                 2,735
# 67                  2 vehicles available                   378
# 68          3 or more vehicles available                    80
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 63                          NaN                  NaN
# 64                         ±567                7,931
# 65                         ±386                59.7%
# 66                         ±554                34.5%
# 67                         ±145                 4.8%
# 68                          ±52                 1.0%
#
#    ZCTA5 02215!!Percent Margin of Error
# 63                                  NaN
# 64                                  (X)
# 65                                 ±5.3
# 66                                 ±5.3
# 67                                 ±1.8
# 68                                 ±0.6
#                     Label (Grouping) ZCTA5 02215!!Estimate  \
# 69                HOUSE HEATING FUEL                   NaN
# 70            Occupied housing units                 7,931
# 71                       Utility gas                 3,293
# 72          Bottled, tank, or LP gas                   126
# 73                       Electricity                 3,481
# 74          Fuel oil, kerosene, etc.                   801
# 75                      Coal or coke                     0
# 76                              Wood                     0
# 77                      Solar energy                    11
# 78                        Other fuel                   112
# 79                      No fuel used                   107
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 69                          NaN                  NaN
# 70                         ±567                7,931
# 71                         ±398                41.5%
# 72                          ±66                 1.6%
# 73                         ±298                43.9%
# 74                         ±464                10.1%
# 75                          ±25                 0.0%
# 76                          ±25                 0.0%
# 77                          ±16                 0.1%
# 78                          ±57                 1.4%
# 79                          ±54                 1.3%
#
#    ZCTA5 02215!!Percent Margin of Error
# 69                                  NaN
# 70                                  (X)
# 71                                 ±5.1
# 72                                 ±0.8
# 73                                 ±4.4
# 74                                 ±5.3
# 75                                 ±0.5
# 76                                 ±0.5
# 77                                 ±0.2
# 78                                 ±0.7
# 79                                 ±0.7
#                                 Label (Grouping) ZCTA5 02215!!Estimate  \
# 80                      SELECTED CHARACTERISTICS                   NaN
# 81                        Occupied housing units                 7,931
# 82          Lacking complete plumbing facilities                   122
# 83           Lacking complete kitchen facilities                   111
# 84                No telephone service available                   164
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 80                          NaN                  NaN
# 81                         ±567                7,931
# 82                          ±80                 1.5%
# 83                          ±70                 1.4%
# 84                          ±81                 2.1%
#
#    ZCTA5 02215!!Percent Margin of Error
# 80                                  NaN
# 81                                  (X)
# 82                                 ±1.0
# 83                                 ±0.9
# 84                                 ±1.0
#               Label (Grouping) ZCTA5 02215!!Estimate  \
# 85          OCCUPANTS PER ROOM                   NaN
# 86      Occupied housing units                 7,931
# 87                1.00 or less                 7,748
# 88                1.01 to 1.50                    55
# 89                1.51 or more                   128
#
#    ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 85                          NaN                  NaN
# 86                         ±567                7,931
# 87                         ±579                97.7%
# 88                          ±67                 0.7%
# 89                          ±85                 1.6%
#
#    ZCTA5 02215!!Percent Margin of Error
# 85                                  NaN
# 86                                  (X)
# 87                                 ±1.4
# 88                                 ±0.8
# 89                                 ±1.1
#                  Label (Grouping) ZCTA5 02215!!Estimate  \
# 90                          VALUE                   NaN
# 91           Owner-occupied units                   703
# 92              Less than $50,000                    12
# 93             $50,000 to $99,999                     0
# 94           $100,000 to $149,999                     0
# 95           $150,000 to $199,999                    12
# 96           $200,000 to $299,999                    47
# 97           $300,000 to $499,999                   289
# 98           $500,000 to $999,999                   194
# 99             $1,000,000 or more                   149
# 100              Median (dollars)               494,900
#
#     ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 90                           NaN                  NaN
# 91                          ±149                  703
# 92                           ±13                 1.7%
# 93                           ±25                 0.0%
# 94                           ±25                 0.0%
# 95                           ±19                 1.7%
# 96                           ±41                 6.7%
# 97                          ±127                41.1%
# 98                           ±62                27.6%
# 99                           ±57                21.2%
# 100                      ±95,263                  (X)
#
#     ZCTA5 02215!!Percent Margin of Error
# 90                                   NaN
# 91                                   (X)
# 92                                  ±1.9
# 93                                  ±5.5
# 94                                  ±5.5
# 95                                  ±2.7
# 96                                  ±6.0
# 97                                 ±12.8
# 98                                  ±8.8
# 99                                  ±8.0
# 100                                  (X)
#                              Label (Grouping) ZCTA5 02215!!Estimate  \
# 101                           MORTGAGE STATUS                   NaN
# 102                      Owner-occupied units                   703
# 103             Housing units with a mortgage                   385
# 104          Housing units without a mortgage                   318
#
#     ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 101                          NaN                  NaN
# 102                         ±149                  703
# 103                         ±119                54.8%
# 104                          ±85                45.2%
#
#     ZCTA5 02215!!Percent Margin of Error
# 101                                  NaN
# 102                                  (X)
# 103                                ±10.0
# 104                                ±10.0
#                          Label (Grouping) ZCTA5 02215!!Estimate  \
# 105   SELECTED MONTHLY OWNER COSTS (SMOC)                   NaN
# 106         Housing units with a mortgage                   385
# 107                        Less than $500                     0
# 108                          $500 to $999                    22
# 109                      $1,000 to $1,499                    32
# 110                      $1,500 to $1,999                   105
# 111                      $2,000 to $2,499                    51
# 112                      $2,500 to $2,999                    86
# 113                        $3,000 or more                    89
# 114                      Median (dollars)                 2,328
# 115      Housing units without a mortgage                   318
# 116                        Less than $250                    24
# 117                          $250 to $399                     8
# 118                          $400 to $599                    13
# 119                          $600 to $799                    75
# 120                          $800 to $999                    26
# 121                        $1,000 or more                   172
# 122                      Median (dollars)                 1,221
#
#     ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 105                          NaN                  NaN
# 106                         ±119                  385
# 107                          ±25                 0.0%
# 108                          ±35                 5.7%
# 109                          ±37                 8.3%
# 110                          ±96                27.3%
# 111                          ±40                13.2%
# 112                          ±52                22.3%
# 113                          ±41                23.1%
# 114                         ±586                  (X)
# 115                          ±85                  318
# 116                          ±25                 7.5%
# 117                          ±12                 2.5%
# 118                          ±14                 4.1%
# 119                          ±50                23.6%
# 120                          ±22                 8.2%
# 121                          ±60                54.1%
# 122                         ±351                  (X)
#
#     ZCTA5 02215!!Percent Margin of Error
# 105                                  NaN
# 106                                  (X)
# 107                                 ±9.9
# 108                                 ±9.1
# 109                                 ±9.7
# 110                                ±20.5
# 111                                ±10.4
# 112                                ±13.2
# 113                                ±10.4
# 114                                  (X)
# 115                                  (X)
# 116                                 ±7.7
# 117                                 ±3.8
# 118                                 ±4.8
# 119                                ±12.9
# 120                                 ±6.8
# 121                                ±13.1
# 122                                  (X)
#                                       Label (Grouping) ZCTA5 02215!!Estimate  \
# 123  SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE O...                   NaN
# 124      Housing units with a mortgage (excluding u...                   385
# 125                             Less than 20.0 percent                    97
# 126                               20.0 to 24.9 percent                   113
# 127                               25.0 to 29.9 percent                    17
# 128                               30.0 to 34.9 percent                    12
# 129                               35.0 percent or more                   146
# 130                                       Not computed                     0
# 131      Housing unit without a mortgage (excluding...                   318
# 132                             Less than 10.0 percent                   125
# 133                               10.0 to 14.9 percent                    24
# 134                               15.0 to 19.9 percent                    38
# 135                               20.0 to 24.9 percent                     0
# 136                               25.0 to 29.9 percent                    27
# 137                               30.0 to 34.9 percent                     0
# 138                               35.0 percent or more                   104
# 139                                       Not computed                     0
#
#     ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 123                          NaN                  NaN
# 124                         ±119                  385
# 125                          ±61                25.2%
# 126                         ±104                29.4%
# 127                          ±22                 4.4%
# 128                          ±14                 3.1%
# 129                          ±47                37.9%
# 130                          ±25                  (X)
# 131                          ±85                  318
# 132                          ±50                39.3%
# 133                          ±24                 7.5%
# 134                          ±27                11.9%
# 135                          ±25                 0.0%
# 136                          ±33                 8.5%
# 137                          ±25                 0.0%
# 138                          ±57                32.7%
# 139                          ±25                  (X)
#
#     ZCTA5 02215!!Percent Margin of Error
# 123                                  NaN
# 124                                  (X)
# 125                                ±15.6
# 126                                ±21.8
# 127                                 ±5.4
# 128                                 ±3.8
# 129                                ±13.0
# 130                                  (X)
# 131                                  (X)
# 132                                ±13.9
# 133                                 ±7.8
# 134                                 ±8.4
# 135                                ±11.8
# 136                                 ±9.9
# 137                                ±11.8
# 138                                ±13.9
# 139                                  (X)
#                    Label (Grouping) ZCTA5 02215!!Estimate  \
# 140                      GROSS RENT                   NaN
# 141      Occupied units paying rent                 7,139
# 142                  Less than $500                   313
# 143                    $500 to $999                   145
# 144                $1,000 to $1,499                   308
# 145                $1,500 to $1,999                 2,185
# 146                $2,000 to $2,499                 1,974
# 147                $2,500 to $2,999                   953
# 148                  $3,000 or more                 1,261
# 149                Median (dollars)                 2,157
# 150                    No rent paid                    89
#
#     ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 140                          NaN                  NaN
# 141                         ±588                7,139
# 142                         ±138                 4.4%
# 143                          ±77                 2.0%
# 144                         ±123                 4.3%
# 145                         ±453                30.6%
# 146                         ±298                27.7%
# 147                         ±200                13.3%
# 148                         ±405                17.7%
# 149                          ±87                  (X)
# 150                          ±59                  (X)
#
#     ZCTA5 02215!!Percent Margin of Error
# 140                                  NaN
# 141                                  (X)
# 142                                 ±2.0
# 143                                 ±1.1
# 144                                 ±1.8
# 145                                 ±5.3
# 146                                 ±4.4
# 147                                 ±2.9
# 148                                 ±4.8
# 149                                  (X)
# 150                                  (X)
#                                       Label (Grouping) ZCTA5 02215!!Estimate  \
# 151  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME...                   NaN
# 152      Occupied units paying rent (excluding unit...                 6,470
# 153                             Less than 15.0 percent                   501
# 154                               15.0 to 19.9 percent                   597
# 155                               20.0 to 24.9 percent                   500
# 156                               25.0 to 29.9 percent                 1,101
# 157                               30.0 to 34.9 percent                   481
# 158                               35.0 percent or more                 3,290
# 159                                       Not computed                   758
#
#     ZCTA5 02215!!Margin of Error ZCTA5 02215!!Percent  \
# 151                          NaN                  NaN
# 152                         ±605                6,470
# 153                         ±175                 7.7%
# 154                         ±172                 9.2%
# 155                         ±159                 7.7%
# 156                         ±428                17.0%
# 157                         ±186                 7.4%
# 158                         ±388                50.9%
# 159                         ±165                  (X)
#
#     ZCTA5 02215!!Percent Margin of Error
# 151                                  NaN
# 152                                  (X)
# 153                                 ±2.7
# 154                                 ±2.5
# 155                                 ±2.4
# 156                                 ±5.5
# 157                                 ±3.0
# 158                                 ±5.7
# 159                                  (X)
