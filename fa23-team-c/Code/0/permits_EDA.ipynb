# %% [markdown]
# ## Approved Building Permits Data

# %%
import pandas as pd

# Load the CSV file into a DataFrame
chunk_size = 100000
data_chunk_1 = pd.read_csv("C:/Users/dimak/OneDrive/Desktop/CS506data/permits_1_data.txt", chunksize= chunk_size)

for chunk in data_chunk_1:
    # Perform EDA on the chunk here
    print(chunk.head()) 

data_chunk_2 = pd.read_csv("C:/Users/dimak/OneDrive/Desktop/CS506data/permits_2_data.txt", chunksize= chunk_size)


for chunk in data_chunk_2:
    # Perform EDA on the chunk here
    print(chunk.head()) 

data_chunk_3 = pd.read_csv("C:/Users/dimak/OneDrive/Desktop/CS506data/permits_3_data.txt", chunksize= chunk_size)


for chunk in data_chunk_3:
    # Perform EDA on the chunk here
    print(chunk.head())
# Out:
# C:\Users\dimak\AppData\Local\Temp\ipykernel_30656\3744342067.py:7: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in data_chunk_1:
#    object_id permitnumber worktype           permittypedescr  \
# 0          1     A1000569   INTEXT  Amendment to a Long Form
# 1          2      A100071      COB  Amendment to a Long Form
# 2          3     A1001012    OTHER  Amendment to a Long Form
# 3          4     A1001201   INTEXT  Amendment to a Long Form
# 4          5      A100137   EXTREN  Amendment to a Long Form
#
#               description                                           comments  \
# 0  Interior/Exterior Work  This work is to Amend Permit ALT347244. Elimin...
# 1          City of Boston  Change connector link layout from attached enc...
# 2                   Other  Amend Alt943748 to erect a roof deck as per pl...
# 3  Interior/Exterior Work  Build steel balcony over garden level with sta...
# ...
